# %% [markdown]
# <h1 style="color: orange; font-size: 36px;">1 MONTH : THE DEVELOPER ARENA TASK </h1>

# %% [markdown]
# <h2 style="color: orange; font-size: 30px;">WEEK 1 : The Developer Arena Task</h2>

# %% [markdown]
# <p style="color: orange; font-size: 25px;">HANDS ON : Average Temperature Calculator</p>

# %%
# Average Temperature Calculator

print("Welcome to Average Temperature Calculator")

# Step 1: Define a list of temperatures
temperatures = [23.5, 25.0, 22.8, 24.1, 26.3]

# Step 2: Calculate total temperature
total = sum(temperatures)

# Step 3: Count how many temperatures
count = len(temperatures)

# Step 4: Calculate average
average = total / count

# Step 5: Display result
print("Temperatures:", temperatures)
print("Total:", total)
print("Number of entries:", count)
print("Average Temperature:", round(average, 2), "°C")
# Out:
# Welcome to Average Temperature Calculator
# Temperatures: [23.5, 25.0, 22.8, 24.1, 26.3]
# Total: 121.7
# Number of entries: 5
# Average Temperature: 24.34 °C

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">HANDS ON : CALCULATOR</h1>

# %%
#Calculator
print("Welcome to Simple Calculator")
print("Choose an operation: +, -, *, /")

# Take input from user
num1 = float(input("Enter first number: "))
print("First Number : ",num1)
op = input("Enter operator: ")
num2 = float(input("Enter second number: "))
print("Second Number : ",num2)

# Perform calculation based on operator
if op == '+':
    print("Result:", num1 + num2)
elif op == '-':
    print("Result:", num1 - num2)
elif op == '*':
    print("Result:", num1 * num2)
elif op == '/':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Cannot divide by zero!")
else:
    print("Invalid operator!")
# Out:
# Welcome to Simple Calculator
# Choose an operation: +, -, *, /
# First Number :  45.0
# Second Number :  5.0
# Result: 225.0

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">CLIENT PROJECT : Average Temperature Calculator</h1>

# %%
#Average Temperature Calculator

def calculate_average_temperature():
    temperatures = []
    print("Enter temperatures (in Celsius). Type 'done' when finished:")

    # Take user input
    entry = input("Enter temperature: ")
    while entry.lower() != 'done':
        if entry.replace('.', '', 1).isdigit():
            temperatures.append(float(entry))
        else:
            print("Please enter a valid number.")
        entry = input("Enter temperature: ")

    # Check if list is not empty
    if len(temperatures) > 0:
        total = sum(temperatures)
        average = total / len(temperatures)
        highest = max(temperatures)
        lowest = min(temperatures)

        # Show results
        print("\n--- Temperature Report ---")
        print("Temperatures:", temperatures)
        print("Total:", round(total, 2), "°C")
        print("Count:", len(temperatures))
        print("Average:", round(average, 2), "°C")
        print("Highest:", highest, "°C")
        print("Lowest:", lowest, "°C")
        print("----------------------------")
    else:
        print("No temperatures entered.")

# Run the program
print("🌡️ Welcome to the Temperature Analyzer 🌡️")
calculate_average_temperature()
# Out:
# 🌡️ Welcome to the Temperature Analyzer 🌡️
# Enter temperatures (in Celsius). Type 'done' when finished:
#
# --- Temperature Report ---
# Temperatures: [5.0, 4.0, 5.0, 5.0]
# Total: 19.0 °C
# Count: 4
# Average: 4.75 °C
# Highest: 5.0 °C
# Lowest: 4.0 °C
# ----------------------------

# %% [markdown]
# <h1 style="color: orange; font-size: 36px;">WEEK 2 : The Developer Arena Task</h1>

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">HANDS-ON PRACTICE</h1>

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">1. Sum of squares using list and function</h1>

# %%
def sum_of_squares(nums):
    return sum([x**2 for x in nums])

numbers = [1, 2, 3, 4]
print("Sum of squares:", sum_of_squares(numbers))  # 30
# Out:
# Sum of squares: 30

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">2. Filter even numbers using lambda and filter()</h1>

# %%
numbers = [1, 2, 3, 4, 5, 6]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print("Even numbers:", even_numbers)  # [2, 4, 6]
# Out:
# Even numbers: [2, 4, 6]

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">CLIENT PROJECT: Data Cleaning Script
# Script to remove duplicates and filter numbers > 10</h1>

# %%
# Data Cleaning Script

def clean_data(data):
    unique_data = list(set(data))  # remove duplicates
    filtered_data = [x for x in unique_data if x > 10]  # keep only numbers > 10
    return filtered_data

# Example data
raw_data = [12, 5, 12, 18, 7, 18, 3, 25]

# Clean the data
cleaned = clean_data(raw_data)
print("Original:", raw_data)
print("Cleaned:", cleaned)
# Out:
# Original: [12, 5, 12, 18, 7, 18, 3, 25]
# Cleaned: [12, 18, 25]

# %% [markdown]
# <h1 style="color: orange; font-size: 36px;">WEEK 3 : The Developer Arena Task</h1>

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">Hands-On Practice</h1>

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">1. NumPy: Array Operations and Broadcasting</h1>

# %%
import numpy as np

# Create a NumPy array
numbers = np.array([10, 20, 30, 40])

# Perform operations
squared = numbers ** 2
added = numbers + 5
mean = np.mean(numbers)

print("Original:", numbers)
print("Squared:", squared)
print("Added +5:", added)
print("Mean:", mean)
# Out:
# Original: [10 20 30 40]
# Squared: [ 100  400  900 1600]
# Added +5: [15 25 35 45]
# Mean: 25.0

# %% [markdown]
# <h1 style="color: orange; font-size: 25px;">2. Pandas: DataFrame Creation & Basic Operations</h1>

# %%
import pandas as pd

# Create a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Math': [85, 90, None, 70],
    'Science': [78, 88, 92, None]
}

df = pd.DataFrame(data)

# View basic info
print("Original DataFrame:")
print(df)

# Drop rows with missing values
cleaned_df = df.dropna()

# Calculate average scores (row-wise)
cleaned_df['Average'] = cleaned_df[['Math', 'Science']].mean(axis=1)

print("\nCleaned DataFrame with Averages:")
print(cleaned_df)
# Out:
# Original DataFrame:
#       Name  Math  Science
# 0    Alice  85.0     78.0
# 1      Bob  90.0     88.0
# 2  Charlie   NaN     92.0
# 3    David  70.0      NaN
#
# Cleaned DataFrame with Averages:
#     Name  Math  Science  Average
# 0  Alice  85.0     78.0     81.5
# 1    Bob  90.0     88.0     89.0
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_4736\3907156339.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Average'] = cleaned_df[['Math', 'Science']].mean(axis=1)

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">Client Project: Clean and Aggregate Dataset</h1>

# %%
import pandas as pd

# Sample dataset
data = {
    'Student': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Class': ['A', 'B', 'A', 'B', 'A'],
    'Math': [85, 90, None, 70, 95],
    'Science': [78, 88, 92, None, 80]
}

df = pd.DataFrame(data)

# Step 1: Fill missing values with column mean
df['Math'].fillna(df['Math'].mean(), inplace=True)
df['Science'].fillna(df['Science'].mean(), inplace=True)

# Step 2: Add average score column
df['Average'] = df[['Math', 'Science']].mean(axis=1)

# Step 3: Group by class and calculate class-wise average
grouped = df.groupby('Class')[['Math', 'Science', 'Average']].mean()

# Print results
print("Cleaned and Aggregated Data:")
print(grouped)
# Out:
# Cleaned and Aggregated Data:
#             Math    Science    Average
# Class
# A      88.333333  83.333333  85.833333
# B      80.000000  86.250000  83.125000
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_4736\1204586626.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Math'].fillna(df['Math'].mean(), inplace=True)
# C:\Users\wwwdh\AppData\Local\Temp\ipykernel_4736\1204586626.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Science'].fillna(df['Science'].mean(), inplace=True)

# %% [markdown]
# <h1 style="color: orange; font-size: 36px;">WEEK 4 : The Developer Arena Task</h1>

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">Hands-On: Visualizations for Dataset Analysis</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset
iris = sns.load_dataset("iris")

# 1. Line Plot (Sepal Length of first 30 flowers)
plt.plot(iris['sepal_length'][:30])
plt.title("Sepal Length of First 30 Flowers")
plt.xlabel("Index")
plt.ylabel("Sepal Length")
plt.grid(True)
plt.show()

# 2. Histogram (Petal Length distribution)
plt.hist(iris['petal_length'], bins=15, color='lightgreen', edgecolor='black')
plt.title("Distribution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# 3. Boxplot (Comparison between species)
sns.boxplot(x="species", y="sepal_width", data=iris)
plt.title("Sepal Width Comparison by Species")
plt.show()

# %% [markdown]
# <h1 style="color: orange; font-size: 30px;">Client Project: Dashboard – Visualizing Relationships</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
iris = sns.load_dataset("iris")

# 1. Scatter Plot: Sepal Length vs Petal Length
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
plt.title("Scatter Plot: Sepal vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# 2. Pairplot: Visual comparison of all features
sns.pairplot(iris, hue='species')
plt.suptitle("Iris Dataset - Pairplot", y=1.02)
plt.show()

# 3. Heatmap: Correlation between numerical features
correlation = iris.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()
